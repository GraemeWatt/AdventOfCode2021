# %% [markdown]
# # Day 4: Giant Squid

# %% [markdown]
# https://adventofcode.com/2021/day/4

# %%
def play_bingo(txt):
    """Play a game of bingo given called numbers and a set of boards."""
    
    # Construct the called numbers and a set of boards from the input text.
    called_numbers, boards = txt.split(maxsplit=1)[0], txt.split(maxsplit=1)[1]
    called_numbers = called_numbers.split(',')
    called_numbers = [int(called_number) for called_number in called_numbers]
    boards = boards.strip().split('\n\n')
    boards = [board.split('\n') for board in boards]
    boards = [[line.split() for line in board] for board in boards]
    boards = [[[[int(number), False] for number in line] for line in board] for board in boards]
    
    # Now let's play Bingo.
    boards_won = [False for board in boards]
    for called_number in called_numbers:
        print(f'Calling number {called_number} ...')
        for i, board in enumerate(boards):
            for j, line in enumerate(board):
                for k, number in enumerate(line):
                    if number[0] == called_number:
                        boards[i][j][k][1] = True
        boards_won = check_status(boards, boards_won, called_number)
        if all(boards_won):
            break

# %%
def check_status(boards, boards_won, called_number):
    """Do we have a winner?  Check the status of all boards."""
    for i, board in enumerate(boards):
        if boards_won[i]:
            continue
        # Check for a complete row of marked numbers.
        for j, row in enumerate(board):
            row_status = [number[1] for number in row]
            if all(row_status):
                #print(f'Board {i+1}, row {j+1} is a winner: {row}')
                boards_won[i] = True
                calculate_score(called_number, board, i)
        # Check for a complete column of marked numbers.
        for k, column in enumerate(zip(*board)):
            column_status = [number[1] for number in column]
            if all(column_status):
                #print(f'Board {i+1}, column {k+1} is a winner: {column}')
                boards_won[i] = True
                calculate_score(called_number, board, i)
    return boards_won

# %%
def calculate_score(called_number, board, i):
    """Calculate the score of the winning board."""
    score = 0
    for row in board:
        for number in row:
            if not number[1]:
                score += number[0]
    #print(f'Sum of all unmarked numbers = {score}, last called_number = {called_number}')
    score *= called_number
    print(f'Bingo for board {i+1}!  Score is {score}.')

# %% [markdown]
# Test the bingo subsystem with the example.

# %%
example_txt = """7,4,9,5,11,17,23,2,0,14,21,24,10,16,13,6,15,25,12,22,18,20,8,19,3,26,1

22 13 17 11  0
 8  2 23  4 24
21  9 14 16  7
 6 10  3 18  5
 1 12 20 15 19

 3 15  0  2 22
 9 18 13 17  5
19  8  7 25 23
20 11 10 24  4
14 21 16 12  6

14 21 17 24  4
10 16 15  9 19
18  8 23 26 20
22 11 13  6  5
 2  0 12  3  7"""

# %%
play_bingo(example_txt)
# Out:
# Calling number 7 ...
# Calling number 4 ...
# Calling number 9 ...
# Calling number 5 ...
# Calling number 11 ...
# Calling number 17 ...
# Calling number 23 ...
# Calling number 2 ...
# Calling number 0 ...
# Calling number 14 ...
# Calling number 21 ...
# Calling number 24 ...
# Bingo for board 3!  Score is 4512.
# Calling number 10 ...
# Calling number 16 ...
# Bingo for board 1!  Score is 2192.
# Calling number 13 ...
# Bingo for board 2!  Score is 1924.

# %% [markdown]
# Now repeat with the input.

# %%
with open('input.txt') as input_file:
    input_txt = input_file.read()

# %%
play_bingo(input_txt)
# Out:
# Calling number 76 ...
# Calling number 69 ...
# Calling number 38 ...
# Calling number 62 ...
# Calling number 33 ...
# Calling number 48 ...
# Calling number 81 ...
# Calling number 2 ...
# Calling number 64 ...
# Calling number 21 ...
# Calling number 80 ...
# Calling number 90 ...
# Calling number 29 ...
# Calling number 99 ...
# Calling number 37 ...
# Calling number 15 ...
# Calling number 93 ...
# Calling number 46 ...
# Calling number 75 ...
# Calling number 0 ...
# Calling number 89 ...
# Calling number 56 ...
# Calling number 58 ...
# Calling number 40 ...
# Calling number 92 ...
# Calling number 47 ...
# Calling number 8 ...
# Calling number 6 ...
# Calling number 54 ...
# Calling number 96 ...
# Calling number 12 ...
# Calling number 66 ...
# Calling number 83 ...
# Calling number 4 ...
# Bingo for board 70!  Score is 2496.
# Calling number 70 ...
# Bingo for board 46!  Score is 60060.
# Bingo for board 84!  Score is 47950.
# Calling number 19 ...
# Calling number 17 ...
# Calling number 5 ...
# Bingo for board 48!  Score is 3875.
# Calling number 50 ...
# Bingo for board 65!  Score is 38000.
# Calling number 52 ...
# Bingo for board 30!  Score is 27872.
# Calling number 45 ...
# Bingo for board 37!  Score is 35505.
# Calling number 51 ...
# Bingo for board 14!  Score is 26775.
# Bingo for board 90!  Score is 26520.
# Calling number 18 ...
# Bingo for board 28!  Score is 15102.
# Bingo for board 41!  Score is 9666.
# Bingo for board 42!  Score is 6084.
# Bingo for board 77!  Score is 14526.
# Calling number 27 ...
# Bingo for board 19!  Score is 9828.
# Bingo for board 22!  Score is 13743.
# Bingo for board 87!  Score is 16686.
# Calling number 49 ...
# Bingo for board 88!  Score is 29057.
# Calling number 71 ...
# Calling number 28 ...
# Bingo for board 6!  Score is 15148.
# Calling number 86 ...
# Bingo for board 15!  Score is 57362.
# Calling number 74 ...
# Bingo for board 3!  Score is 43216.
# Bingo for board 17!  Score is 28194.
# Bingo for board 63!  Score is 37962.
# Calling number 77 ...
# Bingo for board 8!  Score is 51898.
# Bingo for board 91!  Score is 26411.
# Calling number 11 ...
# Bingo for board 9!  Score is 9581.
# Bingo for board 96!  Score is 4763.
# Calling number 20 ...
# Bingo for board 16!  Score is 12840.
# Bingo for board 83!  Score is 14100.
# Calling number 84 ...
# Bingo for board 64!  Score is 51492.
# Bingo for board 73!  Score is 50736.
# Bingo for board 75!  Score is 44604.
# Bingo for board 94!  Score is 39984.
# Bingo for board 95!  Score is 44772.
# Calling number 72 ...
# Calling number 23 ...
# Bingo for board 7!  Score is 13869.
# Bingo for board 23!  Score is 13915.
# Bingo for board 26!  Score is 14329.
# Bingo for board 57!  Score is 12696.
# Calling number 31 ...
# Bingo for board 18!  Score is 11501.
# Bingo for board 60!  Score is 15655.
# Calling number 16 ...
# Bingo for board 32!  Score is 7584.
# Bingo for board 33!  Score is 6336.
# Bingo for board 66!  Score is 9344.
# Calling number 78 ...
# Bingo for board 1!  Score is 44772.
# Calling number 91 ...
# Bingo for board 58!  Score is 37037.
# Calling number 65 ...
# Bingo for board 51!  Score is 31200.
# Bingo for board 56!  Score is 31005.
# Bingo for board 56!  Score is 31005.
# Calling number 87 ...
# Bingo for board 36!  Score is 37758.
# Bingo for board 40!  Score is 41238.
# Bingo for board 71!  Score is 36714.
# Bingo for board 92!  Score is 49677.
# Calling number 79 ...
# Bingo for board 10!  Score is 36340.
# Bingo for board 25!  Score is 26465.
# Bingo for board 43!  Score is 31995.
# Bingo for board 45!  Score is 44161.
# Bingo for board 97!  Score is 27650.
# Calling number 73 ...
# Bingo for board 100!  Score is 27594.
# Calling number 94 ...
# Bingo for board 74!  Score is 43240.
# Calling number 24 ...
# Bingo for board 50!  Score is 6408.
# Bingo for board 69!  Score is 15744.
# Bingo for board 79!  Score is 9144.
# Bingo for board 80!  Score is 8736.
# Bingo for board 86!  Score is 10656.
# Calling number 68 ...
# Bingo for board 31!  Score is 25976.
# Bingo for board 31!  Score is 25976.
# Bingo for board 82!  Score is 26452.
# Bingo for board 89!  Score is 23800.
# Calling number 63 ...
# Bingo for board 85!  Score is 24192.
# Calling number 9 ...
# Bingo for board 34!  Score is 4833.
# Bingo for board 44!  Score is 3555.
# Bingo for board 53!  Score is 3240.
# Bingo for board 68!  Score is 2529.
# Calling number 88 ...
# Bingo for board 93!  Score is 37400.
# Calling number 82 ...
# Bingo for board 4!  Score is 33210.
# Bingo for board 62!  Score is 28864.
# Bingo for board 72!  Score is 18368.
# Calling number 30 ...
# Bingo for board 35!  Score is 5760.
# Bingo for board 54!  Score is 13170.
# Bingo for board 59!  Score is 13170.
# Bingo for board 67!  Score is 10110.
# Bingo for board 78!  Score is 14550.
# Calling number 42 ...
# Bingo for board 13!  Score is 11256.
# Bingo for board 24!  Score is 16926.
# Bingo for board 29!  Score is 14280.
# Bingo for board 38!  Score is 17976.
# Bingo for board 76!  Score is 21252.
# Calling number 60 ...
# Bingo for board 12!  Score is 16920.
# Bingo for board 12!  Score is 16920.
# Bingo for board 21!  Score is 24060.
# Bingo for board 49!  Score is 18240.
# Bingo for board 55!  Score is 17340.
# Bingo for board 61!  Score is 29040.
# Bingo for board 81!  Score is 16620.
# Bingo for board 98!  Score is 12600.
# Bingo for board 98!  Score is 12600.
# Bingo for board 99!  Score is 23820.
# Calling number 13 ...
# Bingo for board 11!  Score is 4316.
# Bingo for board 47!  Score is 2990.
# Calling number 67 ...
# Bingo for board 2!  Score is 16415.
# Bingo for board 52!  Score is 19095.
# Calling number 85 ...
# Calling number 44 ...
# Calling number 59 ...
# Bingo for board 27!  Score is 12980.
# Bingo for board 27!  Score is 12980.
# Calling number 7 ...
# Bingo for board 39!  Score is 2576.
# Calling number 53 ...
# Calling number 22 ...
# Calling number 1 ...
# Bingo for board 5!  Score is 179.
# Bingo for board 5!  Score is 179.
# Calling number 26 ...
# Calling number 41 ...
# Calling number 61 ...
# Bingo for board 20!  Score is 25925.
