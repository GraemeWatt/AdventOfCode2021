# %% [markdown]
# # Day 6: Lanternfish

# %% [markdown]
# https://adventofcode.com/2021/day/6

# %% [markdown]
# ## Part 1

# %%
import numpy as np  # start to use NumPy arrays for speed instead of normal Python lists

# %%
class Lanternfish:
    """A simulation of spawning lanternfish."""
    def __init__(self, txt, verbose=False):
        print(f'Initial state: {txt}')
        self.l = np.array(list(map(int, txt.split(','))))  # initial list of lanternfish
        self.verbose = verbose  # option to print out the list for each day
        self.day = 0
    def count(self):
        """Count number of lanternfish in the list."""
        status = f'After {" " if self.day < 10 else ""}{self.day} '
        status += f'day{"s" if self.day > 1 else ""}: '
        status += f'{"" if self.day > 1 else " "}'
        status += f'total of {self.l.size} fish.'
        print(status)
    def add_days(self, num_days):
        """Spawn for a number of days."""
        for day in range(num_days):
            self.add_day()
    def add_day(self):
        """Spawn for a single day."""
        self.day += 1  # add 1 to day
        self.l -= 1  # subtract 1 from internal timer of each lanternfish
        new_fish = self.l[self.l < 0].size  # number of new lanternfish
        self.l[self.l < 0] = 6  # reset internal timer to 6
        # create a new lanternfish with an internal timer of 8
        self.l = np.append(self.l, 8*np.ones(new_fish, dtype=int))
        if self.verbose:
            status = f'After {" " if self.day < 10 else ""}{self.day} '
            status += f'day{"s" if self.day > 1 else ""}: '
            status += f'{"" if self.day > 1 else " "}{",".join(map(str, self.l))}'
            print(status)
        self.count()

# %% [markdown]
# Test with the example.

# %%
example_txt = """3,4,3,1,2"""

# %%
lanternfish = Lanternfish(example_txt, verbose=True)
lanternfish.add_days(18)
# Out:
# Initial state: 3,4,3,1,2
# After  1 day:  2,3,2,0,1
# After  1 day:  total of 5 fish.
# After  2 days: 1,2,1,6,0,8
# After  2 days: total of 6 fish.
# After  3 days: 0,1,0,5,6,7,8
# After  3 days: total of 7 fish.
# After  4 days: 6,0,6,4,5,6,7,8,8
# After  4 days: total of 9 fish.
# After  5 days: 5,6,5,3,4,5,6,7,7,8
# After  5 days: total of 10 fish.
# After  6 days: 4,5,4,2,3,4,5,6,6,7
# After  6 days: total of 10 fish.
# After  7 days: 3,4,3,1,2,3,4,5,5,6
# After  7 days: total of 10 fish.
# After  8 days: 2,3,2,0,1,2,3,4,4,5
# After  8 days: total of 10 fish.
# After  9 days: 1,2,1,6,0,1,2,3,3,4,8
# After  9 days: total of 11 fish.
# After 10 days: 0,1,0,5,6,0,1,2,2,3,7,8
# After 10 days: total of 12 fish.
# After 11 days: 6,0,6,4,5,6,0,1,1,2,6,7,8,8,8
# After 11 days: total of 15 fish.
# After 12 days: 5,6,5,3,4,5,6,0,0,1,5,6,7,7,7,8,8
# After 12 days: total of 17 fish.
# After 13 days: 4,5,4,2,3,4,5,6,6,0,4,5,6,6,6,7,7,8,8
# After 13 days: total of 19 fish.
# After 14 days: 3,4,3,1,2,3,4,5,5,6,3,4,5,5,5,6,6,7,7,8
# After 14 days: total of 20 fish.
# After 15 days: 2,3,2,0,1,2,3,4,4,5,2,3,4,4,4,5,5,6,6,7
# After 15 days: total of 20 fish.
# After 16 days: 1,2,1,6,0,1,2,3,3,4,1,2,3,3,3,4,4,5,5,6,8
# After 16 days: total of 21 fish.
# After 17 days: 0,1,0,5,6,0,1,2,2,3,0,1,2,2,2,3,3,4,4,5,7,8
# After 17 days: total of 22 fish.
# After 18 days: 6,0,6,4,5,6,0,1,1,2,6,0,1,1,1,2,2,3,3,4,6,7,8,8,8,8
# After 18 days: total of 26 fish.

# %% [markdown]
# Now repeat with the input.

# %%
with open('input.txt') as input_file:
    input_txt = input_file.read().strip()

# %%
lanternfish = Lanternfish(input_txt)
lanternfish.add_days(80)
# Out:
# Initial state: 2,1,1,4,4,1,3,4,2,4,2,1,1,4,3,5,1,1,5,1,1,5,4,5,4,1,5,1,3,1,4,2,3,2,1,2,5,5,2,3,1,2,3,3,1,4,3,1,1,1,1,5,2,1,1,1,5,3,3,2,1,4,1,1,1,3,1,1,5,5,1,4,4,4,4,5,1,5,1,1,5,5,2,2,5,4,1,5,4,1,4,1,1,1,1,5,3,2,4,1,1,1,4,4,1,2,1,1,5,2,1,1,1,4,4,4,4,3,3,1,1,5,1,5,2,1,4,1,2,4,4,4,4,2,2,2,4,4,4,2,1,5,5,2,1,1,1,4,4,1,4,2,3,3,3,3,3,5,4,1,5,1,4,5,5,1,1,1,4,1,2,4,4,1,2,3,3,3,3,5,1,4,2,5,5,2,1,1,1,1,3,3,1,1,2,3,2,5,4,2,1,1,2,2,2,1,3,1,5,4,1,1,5,3,3,2,2,3,1,1,1,1,2,4,2,2,5,1,2,4,2,1,1,3,2,5,5,3,1,3,3,1,4,1,1,5,5,1,5,4,1,1,1,1,2,3,3,1,2,3,1,5,1,3,1,1,3,1,1,1,1,1,1,5,1,1,5,5,2,1,1,5,2,4,5,5,1,1,5,1,5,5,1,1,3,3,1,1,3,1
# After  1 day:  total of 300 fish.
# After  2 days: total of 416 fish.
# After  3 days: total of 461 fish.
# After  4 days: total of 503 fish.
# After  5 days: total of 551 fish.
# After  6 days: total of 600 fish.
# After  7 days: total of 600 fish.
# After  8 days: total of 600 fish.
# After  9 days: total of 716 fish.
# After 10 days: total of 761 fish.
# After 11 days: total of 919 fish.
# After 12 days: total of 1012 fish.
# After 13 days: total of 1103 fish.
# After 14 days: total of 1151 fish.
# After 15 days: total of 1200 fish.
# After 16 days: total of 1316 fish.
# After 17 days: total of 1361 fish.
# After 18 days: total of 1635 fish.
# After 19 days: total of 1773 fish.
# After 20 days: total of 2022 fish.
# After 21 days: total of 2163 fish.
# After 22 days: total of 2303 fish.
# After 23 days: total of 2467 fish.
# After 24 days: total of 2561 fish.
# After 25 days: total of 2951 fish.
# After 26 days: total of 3134 fish.
# After 27 days: total of 3657 fish.
# After 28 days: total of 3936 fish.
# After 29 days: total of 4325 fish.
# After 30 days: total of 4630 fish.
# After 31 days: total of 4864 fish.
# After 32 days: total of 5418 fish.
# After 33 days: total of 5695 fish.
# After 34 days: total of 6608 fish.
# After 35 days: total of 7070 fish.
# After 36 days: total of 7982 fish.
# After 37 days: total of 8566 fish.
# After 38 days: total of 9189 fish.
# After 39 days: total of 10048 fish.
# After 40 days: total of 10559 fish.
# After 41 days: total of 12026 fish.
# After 42 days: total of 12765 fish.
# After 43 days: total of 14590 fish.
# After 44 days: total of 15636 fish.
# After 45 days: total of 17171 fish.
# After 46 days: total of 18614 fish.
# After 47 days: total of 19748 fish.
# After 48 days: total of 22074 fish.
# After 49 days: total of 23324 fish.
# After 50 days: total of 26616 fish.
# After 51 days: total of 28401 fish.
# After 52 days: total of 31761 fish.
# After 53 days: total of 34250 fish.
# After 54 days: total of 36919 fish.
# After 55 days: total of 40688 fish.
# After 56 days: total of 43072 fish.
# After 57 days: total of 48690 fish.
# After 58 days: total of 51725 fish.
# After 59 days: total of 58377 fish.
# After 60 days: total of 62651 fish.
# After 61 days: total of 68680 fish.
# After 62 days: total of 74938 fish.
# After 63 days: total of 79991 fish.
# After 64 days: total of 89378 fish.
# After 65 days: total of 94797 fish.
# After 66 days: total of 107067 fish.
# After 67 days: total of 114376 fish.
# After 68 days: total of 127057 fish.
# After 69 days: total of 137589 fish.
# After 70 days: total of 148671 fish.
# After 71 days: total of 164316 fish.
# After 72 days: total of 174788 fish.
# After 73 days: total of 196445 fish.
# After 74 days: total of 209173 fish.
# After 75 days: total of 234124 fish.
# After 76 days: total of 251965 fish.
# After 77 days: total of 275728 fish.
# After 78 days: total of 301905 fish.
# After 79 days: total of 323459 fish.
# After 80 days: total of 360761 fish.

# %% [markdown]
# ## Part 2

# %% [markdown]
# The solution from Part 1 does not scale well for 256 days, where it takes prohibitively long to calculate.  Rewriting my original attempt using normal Python lists to instead use NumPy arrays did not help much.  Instead, we can construct a smarter solution by recognising that it is not necessary to retain the complete list of lanternfish at each step.  Only the number of lanternfish with each timer value (from 0 to 8) needs to be stored.

# %%
class SmarterLanternfish:
    """A smarter simulation of spawning lanternfish."""
    def __init__(self, txt, verbose=False):
        initial = list(map(int, txt.split(',')))
        # Count how many lanternfish in the initial list have a certain timer.
        self.l = np.array([initial.count(timer) for timer in range(0, 9)])
        self.verbose = verbose  # option to print out the list for each day
        self.day = 0
        if self.verbose:
            print(f'Initial state:  {",".join(map(str, self.l))}')
    def add_days(self, days):
        """Spawn for a number of days."""
        for day in range(days):
            self.add_day()
    def add_day(self):
        """Spawn for a single day."""
        self.day += 1  # add 1 to day
        new_fish = self.l[0]  # new lanternfish
        # Roll array elements to subtract 1 from internal timer.
        self.l = np.roll(self.l, -1)
        self.l[6] += new_fish  # reset internal timer to 6
        if self.verbose:
            status = f'After {(3-len(str(self.day)))*" "}{self.day} '
            status += f'day{"s" if self.day > 1 else ""}: '
            status += f'{"" if self.day > 1 else " "}{",".join(map(str, self.l[:9]))}'
            print(status)
        self.count()
    def count(self):
        """Count number of lanternfish in the list."""
        status = f'After {(3-len(str(self.day)))*" "}{self.day} '
        status += f'day{"s" if self.day > 1 else ""}: '
        status += f'{"" if self.day > 1 else " "}'
        status += f'total of {np.sum(self.l)} fish.'
        print(status)

# %%
# %%time
lanternfish = SmarterLanternfish(example_txt, verbose=True)
lanternfish.add_days(256)
# Out:
# Initial state:  0,1,1,2,1,0,0,0,0
# After   1 day:  1,1,2,1,0,0,0,0,0
# After   1 day:  total of 5 fish.
# After   2 days: 1,2,1,0,0,0,1,0,1
# After   2 days: total of 6 fish.
# After   3 days: 2,1,0,0,0,1,1,1,1
# After   3 days: total of 7 fish.
# After   4 days: 1,0,0,0,1,1,3,1,2
# After   4 days: total of 9 fish.
# After   5 days: 0,0,0,1,1,3,2,2,1
# After   5 days: total of 10 fish.
# After   6 days: 0,0,1,1,3,2,2,1,0
# After   6 days: total of 10 fish.
# After   7 days: 0,1,1,3,2,2,1,0,0
# After   7 days: total of 10 fish.
# After   8 days: 1,1,3,2,2,1,0,0,0
# After   8 days: total of 10 fish.
# After   9 days: 1,3,2,2,1,0,1,0,1
# After   9 days: total of 11 fish.
# After  10 days: 3,2,2,1,0,1,1,1,1
# After  10 days: total of 12 fish.
# After  11 days: 2,2,1,0,1,1,4,1,3
# After  11 days: total of 15 fish.
# After  12 days: 2,1,0,1,1,4,3,3,2
# After  12 days: total of 17 fish.
# After  13 days: 1,0,1,1,4,3,5,2,2
# After  13 days: total of 19 fish.
# After  14 days: 0,1,1,4,3,5,3,2,1
# After  14 days: total of 20 fish.
# After  15 days: 1,1,4,3,5,3,2,1,0
# After  15 days: total of 20 fish.
# After  16 days: 1,4,3,5,3,2,2,0,1
# After  16 days: total of 21 fish.
# After  17 days: 4,3,5,3,2,2,1,1,1
# After  17 days: total of 22 fish.
# After  18 days: 3,5,3,2,2,1,5,1,4
# After  18 days: total of 26 fish.
# After  19 days: 5,3,2,2,1,5,4,4,3
# After  19 days: total of 29 fish.
# After  20 days: 3,2,2,1,5,4,9,3,5
# After  20 days: total of 34 fish.
# After  21 days: 2,2,1,5,4,9,6,5,3
# After  21 days: total of 37 fish.
# After  22 days: 2,1,5,4,9,6,7,3,2
# After  22 days: total of 39 fish.
# After  23 days: 1,5,4,9,6,7,5,2,2
# After  23 days: total of 41 fish.
# After  24 days: 5,4,9,6,7,5,3,2,1
# After  24 days: total of 42 fish.
# After  25 days: 4,9,6,7,5,3,7,1,5
# After  25 days: total of 47 fish.
# After  26 days: 9,6,7,5,3,7,5,5,4
# After  26 days: total of 51 fish.
# After  27 days: 6,7,5,3,7,5,14,4,9
# After  27 days: total of 60 fish.
# After  28 days: 7,5,3,7,5,14,10,9,6
# After  28 days: total of 66 fish.
# After  29 days: 5,3,7,5,14,10,16,6,7
# After  29 days: total of 73 fish.
# After  30 days: 3,7,5,14,10,16,11,7,5
# After  30 days: total of 78 fish.
# After  31 days: 7,5,14,10,16,11,10,5,3
# After  31 days: total of 81 fish.
# After  32 days: 5,14,10,16,11,10,12,3,7
# After  32 days: total of 88 fish.
# After  33 days: 14,10,16,11,10,12,8,7,5
# After  33 days: total of 93 fish.
# After  34 days: 10,16,11,10,12,8,21,5,14
# After  34 days: total of 107 fish.
# After  35 days: 16,11,10,12,8,21,15,14,10
# After  35 days: total of 117 fish.
# After  36 days: 11,10,12,8,21,15,30,10,16
# After  36 days: total of 133 fish.
# After  37 days: 10,12,8,21,15,30,21,16,11
# After  37 days: total of 144 fish.
# After  38 days: 12,8,21,15,30,21,26,11,10
# After  38 days: total of 154 fish.
# After  39 days: 8,21,15,30,21,26,23,10,12
# After  39 days: total of 166 fish.
# After  40 days: 21,15,30,21,26,23,18,12,8
# After  40 days: total of 174 fish.
# After  41 days: 15,30,21,26,23,18,33,8,21
# After  41 days: total of 195 fish.
# After  42 days: 30,21,26,23,18,33,23,21,15
# After  42 days: total of 210 fish.
# After  43 days: 21,26,23,18,33,23,51,15,30
# After  43 days: total of 240 fish.
# After  44 days: 26,23,18,33,23,51,36,30,21
# After  44 days: total of 261 fish.
# After  45 days: 23,18,33,23,51,36,56,21,26
# After  45 days: total of 287 fish.
# After  46 days: 18,33,23,51,36,56,44,26,23
# After  46 days: total of 310 fish.
# After  47 days: 33,23,51,36,56,44,44,23,18
# After  47 days: total of 328 fish.
# After  48 days: 23,51,36,56,44,44,56,18,33
# After  48 days: total of 361 fish.
# After  49 days: 51,36,56,44,44,56,41,33,23
# After  49 days: total of 384 fish.
# After  50 days: 36,56,44,44,56,41,84,23,51
# After  50 days: total of 435 fish.
# After  51 days: 56,44,44,56,41,84,59,51,36
# After  51 days: total of 471 fish.
# After  52 days: 44,44,56,41,84,59,107,36,56
# After  52 days: total of 527 fish.
# After  53 days: 44,56,41,84,59,107,80,56,44
# After  53 days: total of 571 fish.
# After  54 days: 56,41,84,59,107,80,100,44,44
# After  54 days: total of 615 fish.
# After  55 days: 41,84,59,107,80,100,100,44,56
# After  55 days: total of 671 fish.
# After  56 days: 84,59,107,80,100,100,85,56,41
# After  56 days: total of 712 fish.
# After  57 days: 59,107,80,100,100,85,140,41,84
# After  57 days: total of 796 fish.
# After  58 days: 107,80,100,100,85,140,100,84,59
# After  58 days: total of 855 fish.
# After  59 days: 80,100,100,85,140,100,191,59,107
# After  59 days: total of 962 fish.
# After  60 days: 100,100,85,140,100,191,139,107,80
# After  60 days: total of 1042 fish.
# After  61 days: 100,85,140,100,191,139,207,80,100
# After  61 days: total of 1142 fish.
# After  62 days: 85,140,100,191,139,207,180,100,100
# After  62 days: total of 1242 fish.
# After  63 days: 140,100,191,139,207,180,185,100,85
# After  63 days: total of 1327 fish.
# After  64 days: 100,191,139,207,180,185,240,85,140
# After  64 days: total of 1467 fish.
# After  65 days: 191,139,207,180,185,240,185,140,100
# After  65 days: total of 1567 fish.
# After  66 days: 139,207,180,185,240,185,331,100,191
# After  66 days: total of 1758 fish.
# After  67 days: 207,180,185,240,185,331,239,191,139
# After  67 days: total of 1897 fish.
# After  68 days: 180,185,240,185,331,239,398,139,207
# After  68 days: total of 2104 fish.
# After  69 days: 185,240,185,331,239,398,319,207,180
# After  69 days: total of 2284 fish.
# After  70 days: 240,185,331,239,398,319,392,180,185
# After  70 days: total of 2469 fish.
# After  71 days: 185,331,239,398,319,392,420,185,240
# After  71 days: total of 2709 fish.
# After  72 days: 331,239,398,319,392,420,370,240,185
# After  72 days: total of 2894 fish.
# After  73 days: 239,398,319,392,420,370,571,185,331
# After  73 days: total of 3225 fish.
# After  74 days: 398,319,392,420,370,571,424,331,239
# After  74 days: total of 3464 fish.
# After  75 days: 319,392,420,370,571,424,729,239,398
# After  75 days: total of 3862 fish.
# After  76 days: 392,420,370,571,424,729,558,398,319
# After  76 days: total of 4181 fish.
# After  77 days: 420,370,571,424,729,558,790,319,392
# After  77 days: total of 4573 fish.
# After  78 days: 370,571,424,729,558,790,739,392,420
# After  78 days: total of 4993 fish.
# After  79 days: 571,424,729,558,790,739,762,420,370
# After  79 days: total of 5363 fish.
# After  80 days: 424,729,558,790,739,762,991,370,571
# After  80 days: total of 5934 fish.
# After  81 days: 729,558,790,739,762,991,794,571,424
# After  81 days: total of 6358 fish.
# After  82 days: 558,790,739,762,991,794,1300,424,729
# After  82 days: total of 7087 fish.
# After  83 days: 790,739,762,991,794,1300,982,729,558
# After  83 days: total of 7645 fish.
# After  84 days: 739,762,991,794,1300,982,1519,558,790
# After  84 days: total of 8435 fish.
# After  85 days: 762,991,794,1300,982,1519,1297,790,739
# After  85 days: total of 9174 fish.
# After  86 days: 991,794,1300,982,1519,1297,1552,739,762
# After  86 days: total of 9936 fish.
# After  87 days: 794,1300,982,1519,1297,1552,1730,762,991
# After  87 days: total of 10927 fish.
# After  88 days: 1300,982,1519,1297,1552,1730,1556,991,794
# After  88 days: total of 11721 fish.
# After  89 days: 982,1519,1297,1552,1730,1556,2291,794,1300
# After  89 days: total of 13021 fish.
# After  90 days: 1519,1297,1552,1730,1556,2291,1776,1300,982
# After  90 days: total of 14003 fish.
# After  91 days: 1297,1552,1730,1556,2291,1776,2819,982,1519
# After  91 days: total of 15522 fish.
# After  92 days: 1552,1730,1556,2291,1776,2819,2279,1519,1297
# After  92 days: total of 16819 fish.
# After  93 days: 1730,1556,2291,1776,2819,2279,3071,1297,1552
# After  93 days: total of 18371 fish.
# After  94 days: 1556,2291,1776,2819,2279,3071,3027,1552,1730
# After  94 days: total of 20101 fish.
# After  95 days: 2291,1776,2819,2279,3071,3027,3108,1730,1556
# After  95 days: total of 21657 fish.
# After  96 days: 1776,2819,2279,3071,3027,3108,4021,1556,2291
# After  96 days: total of 23948 fish.
# After  97 days: 2819,2279,3071,3027,3108,4021,3332,2291,1776
# After  97 days: total of 25724 fish.
# After  98 days: 2279,3071,3027,3108,4021,3332,5110,1776,2819
# After  98 days: total of 28543 fish.
# After  99 days: 3071,3027,3108,4021,3332,5110,4055,2819,2279
# After  99 days: total of 30822 fish.
# After 100 days: 3027,3108,4021,3332,5110,4055,5890,2279,3071
# After 100 days: total of 33893 fish.
# After 101 days: 3108,4021,3332,5110,4055,5890,5306,3071,3027
# After 101 days: total of 36920 fish.
# After 102 days: 4021,3332,5110,4055,5890,5306,6179,3027,3108
# After 102 days: total of 40028 fish.
# After 103 days: 3332,5110,4055,5890,5306,6179,7048,3108,4021
# After 103 days: total of 44049 fish.
# After 104 days: 5110,4055,5890,5306,6179,7048,6440,4021,3332
# After 104 days: total of 47381 fish.
# After 105 days: 4055,5890,5306,6179,7048,6440,9131,3332,5110
# After 105 days: total of 52491 fish.
# After 106 days: 5890,5306,6179,7048,6440,9131,7387,5110,4055
# After 106 days: total of 56546 fish.
# After 107 days: 5306,6179,7048,6440,9131,7387,11000,4055,5890
# After 107 days: total of 62436 fish.
# After 108 days: 6179,7048,6440,9131,7387,11000,9361,5890,5306
# After 108 days: total of 67742 fish.
# After 109 days: 7048,6440,9131,7387,11000,9361,12069,5306,6179
# After 109 days: total of 73921 fish.
# After 110 days: 6440,9131,7387,11000,9361,12069,12354,6179,7048
# After 110 days: total of 80969 fish.
# After 111 days: 9131,7387,11000,9361,12069,12354,12619,7048,6440
# After 111 days: total of 87409 fish.
# After 112 days: 7387,11000,9361,12069,12354,12619,16179,6440,9131
# After 112 days: total of 96540 fish.
# After 113 days: 11000,9361,12069,12354,12619,16179,13827,9131,7387
# After 113 days: total of 103927 fish.
# After 114 days: 9361,12069,12354,12619,16179,13827,20131,7387,11000
# After 114 days: total of 114927 fish.
# After 115 days: 12069,12354,12619,16179,13827,20131,16748,11000,9361
# After 115 days: total of 124288 fish.
# After 116 days: 12354,12619,16179,13827,20131,16748,23069,9361,12069
# After 116 days: total of 136357 fish.
# After 117 days: 12619,16179,13827,20131,16748,23069,21715,12069,12354
# After 117 days: total of 148711 fish.
# After 118 days: 16179,13827,20131,16748,23069,21715,24688,12354,12619
# After 118 days: total of 161330 fish.
# After 119 days: 13827,20131,16748,23069,21715,24688,28533,12619,16179
# After 119 days: total of 177509 fish.
# After 120 days: 20131,16748,23069,21715,24688,28533,26446,16179,13827
# After 120 days: total of 191336 fish.
# After 121 days: 16748,23069,21715,24688,28533,26446,36310,13827,20131
# After 121 days: total of 211467 fish.
# After 122 days: 23069,21715,24688,28533,26446,36310,30575,20131,16748
# After 122 days: total of 228215 fish.
# After 123 days: 21715,24688,28533,26446,36310,30575,43200,16748,23069
# After 123 days: total of 251284 fish.
# After 124 days: 24688,28533,26446,36310,30575,43200,38463,23069,21715
# After 124 days: total of 272999 fish.
# After 125 days: 28533,26446,36310,30575,43200,38463,47757,21715,24688
# After 125 days: total of 297687 fish.
# After 126 days: 26446,36310,30575,43200,38463,47757,50248,24688,28533
# After 126 days: total of 326220 fish.
# After 127 days: 36310,30575,43200,38463,47757,50248,51134,28533,26446
# After 127 days: total of 352666 fish.
# After 128 days: 30575,43200,38463,47757,50248,51134,64843,26446,36310
# After 128 days: total of 388976 fish.
# After 129 days: 43200,38463,47757,50248,51134,64843,57021,36310,30575
# After 129 days: total of 419551 fish.
# After 130 days: 38463,47757,50248,51134,64843,57021,79510,30575,43200
# After 130 days: total of 462751 fish.
# After 131 days: 47757,50248,51134,64843,57021,79510,69038,43200,38463
# After 131 days: total of 501214 fish.
# After 132 days: 50248,51134,64843,57021,79510,69038,90957,38463,47757
# After 132 days: total of 548971 fish.
# After 133 days: 51134,64843,57021,79510,69038,90957,88711,47757,50248
# After 133 days: total of 599219 fish.
# After   4 days: total of 503 fish.
# After   5 days: total of 551 fish.
# After   6 days: total of 600 fish.
# After   7 days: total of 600 fish.
# After   8 days: total of 600 fish.
# After   9 days: total of 716 fish.
# After  10 days: total of 761 fish.
# After  11 days: total of 919 fish.
# After  12 days: total of 1012 fish.
# After  13 days: total of 1103 fish.
# After  14 days: total of 1151 fish.
# After  15 days: total of 1200 fish.
# After  16 days: total of 1316 fish.
# After  17 days: total of 1361 fish.
# After  18 days: total of 1635 fish.
# After  19 days: total of 1773 fish.
# After  20 days: total of 2022 fish.
# After  21 days: total of 2163 fish.
# After  22 days: total of 2303 fish.
# After  23 days: total of 2467 fish.
# After  24 days: total of 2561 fish.
# After  25 days: total of 2951 fish.
# After  26 days: total of 3134 fish.
# After  27 days: total of 3657 fish.
# After  28 days: total of 3936 fish.
# After  29 days: total of 4325 fish.
# After  30 days: total of 4630 fish.
# After  31 days: total of 4864 fish.
# After  32 days: total of 5418 fish.
# After  33 days: total of 5695 fish.
# After  34 days: total of 6608 fish.
# After  35 days: total of 7070 fish.
# After  36 days: total of 7982 fish.
# After  37 days: total of 8566 fish.
# After  38 days: total of 9189 fish.
# After  39 days: total of 10048 fish.
# After  40 days: total of 10559 fish.
# After  41 days: total of 12026 fish.
# After  42 days: total of 12765 fish.
# After  43 days: total of 14590 fish.
# After  44 days: total of 15636 fish.
# After  45 days: total of 17171 fish.
# After  46 days: total of 18614 fish.
# After  47 days: total of 19748 fish.
# After  48 days: total of 22074 fish.
# After  49 days: total of 23324 fish.
# After  50 days: total of 26616 fish.
# After  51 days: total of 28401 fish.
# After  52 days: total of 31761 fish.
# After  53 days: total of 34250 fish.
# After  54 days: total of 36919 fish.
# After  55 days: total of 40688 fish.
# After  56 days: total of 43072 fish.
# After  57 days: total of 48690 fish.
# After  58 days: total of 51725 fish.
# After  59 days: total of 58377 fish.
# After  60 days: total of 62651 fish.
# After  61 days: total of 68680 fish.
# After  62 days: total of 74938 fish.
# After  63 days: total of 79991 fish.
# After  64 days: total of 89378 fish.
# After  65 days: total of 94797 fish.
# After  66 days: total of 107067 fish.
# After  67 days: total of 114376 fish.
# After  68 days: total of 127057 fish.
# After  69 days: total of 137589 fish.
# After  70 days: total of 148671 fish.
# After  71 days: total of 164316 fish.
# After  72 days: total of 174788 fish.
# After  73 days: total of 196445 fish.
# After  74 days: total of 209173 fish.
# After  75 days: total of 234124 fish.
# After  76 days: total of 251965 fish.
# After  77 days: total of 275728 fish.
# After  78 days: total of 301905 fish.
# After  79 days: total of 323459 fish.
# After  80 days: total of 360761 fish.
# After  81 days: total of 383961 fish.
# After  82 days: total of 430569 fish.
# After  83 days: total of 461138 fish.
# After  84 days: total of 509852 fish.
# After  85 days: total of 553870 fish.
# After  86 days: total of 599187 fish.
# After  87 days: total of 662666 fish.
# After  88 days: total of 707420 fish.
# After  89 days: total of 791330 fish.
# After  90 days: total of 845099 fish.
# After  91 days: total of 940421 fish.
# After  92 days: total of 1015008 fish.
# After  93 days: total of 1109039 fish.
# After  94 days: total of 1216536 fish.
# After  95 days: total of 1306607 fish.
# After  96 days: total of 1453996 fish.
# After  97 days: total of 1552519 fish.
# After  98 days: total of 1731751 fish.
# After  99 days: total of 1860107 fish.
# After 100 days: total of 2049460 fish.
# After 101 days: total of 2231544 fish.
# After 102 days: total of 2415646 fish.
# After 103 days: total of 2670532 fish.
# After 104 days: total of 2859126 fish.
# After 105 days: total of 3185747 fish.
# After 106 days: total of 3412626 fish.
# After 107 days: total of 3781211 fish.
# After 108 days: total of 4091651 fish.
# After 109 days: total of 4465106 fish.
# After 110 days: total of 4902076 fish.
# After 111 days: total of 5274772 fish.
# After 112 days: total of 5856279 fish.
# After 113 days: total of 6271752 fish.
# After 114 days: total of 6966958 fish.
# After 115 days: total of 7504277 fish.
# After 116 days: total of 8246317 fish.
# After 117 days: total of 8993727 fish.
# After 118 days: total of 9739878 fish.
# After 119 days: total of 10758355 fish.
# After 120 days: total of 11546524 fish.
# After 121 days: total of 12823237 fish.
# After 122 days: total of 13776029 fish.
# After 123 days: total of 15213275 fish.
# After 124 days: total of 16498004 fish.
# After 125 days: total of 17986195 fish.
# After 126 days: total of 19752082 fish.
# After 127 days: total of 21286402 fish.
# After 128 days: total of 23581592 fish.
# After 129 days: total of 25322553 fish.
# After 130 days: total of 28036512 fish.
# After 131 days: total of 30274033 fish.
# After 132 days: total of 33199470 fish.
# After 133 days: total of 36250086 fish.
# After 134 days: total of 39272597 fish.
# After 135 days: total of 43333674 fish.
# After 136 days: total of 46608955 fish.
# After 137 days: total of 51618104 fish.
# After 138 days: total of 55596586 fish.
# After 139 days: total of 61235982 fish.
# After 140 days: total of 66524119 fish.
# After 141 days: total of 72472067 fish.
# After 142 days: total of 79583760 fish.
# After 143 days: total of 85881552 fish.
# After 144 days: total of 94951778 fish.
# After 145 days: total of 102205541 fish.
# After 146 days: total of 112854086 fish.
# After 147 days: total of 122120705 fish.
# After 148 days: total of 133708049 fish.
# After 149 days: total of 146107879 fish.
# After 150 days: total of 158353619 fish.
# After 151 days: total of 174535538 fish.
# After 152 days: total of 188087093 fish.
# After 153 days: total of 207805864 fish.
# After 154 days: total of 224326246 fish.
# After 155 days: total of 246562135 fish.
# After 156 days: total of 268228584 fish.
# After 157 days: total of 292061668 fish.
# After 158 days: total of 320643417 fish.
# After 159 days: total of 346440712 fish.
# After 160 days: total of 382341402 fish.
# After 161 days: total of 412413339 fish.
# After 162 days: total of 454367999 fish.
# After 163 days: total of 492554830 fish.
# After 164 days: total of 538623803 fish.
# After 165 days: total of 588872001 fish.
# After 166 days: total of 638502380 fish.
# After 167 days: total of 702984819 fish.
# After 168 days: total of 758854051 fish.
# After 169 days: total of 836709401 fish.
# After 170 days: total of 904968169 fish.
# After 171 days: total of 992991802 fish.
# After 172 days: total of 1081426831 fish.
# After 173 days: total of 1177126183 fish.
# After 174 days: total of 1291856820 fish.
# After 175 days: total of 1397356431 fish.
# After 176 days: total of 1539694220 fish.
# After 177 days: total of 1663822220 fish.
# After 178 days: total of 1829701203 fish.
# After 179 days: total of 1986395000 fish.
# After 180 days: total of 2170117985 fish.
# After 181 days: total of 2373283651 fish.
# After 182 days: total of 2574482614 fish.
# After 183 days: total of 2831551040 fish.
# After 184 days: total of 3061178651 fish.
# After 185 days: total of 3369395423 fish.
# After 186 days: total of 3650217220 fish.
# After 187 days: total of 3999819188 fish.
# After 188 days: total of 4359678651 fish.
# After 189 days: total of 4744600599 fish.
# After 190 days: total of 5204834691 fish.
# After 191 days: total of 5635661265 fish.
# After 192 days: total of 6200946463 fish.
# After 193 days: total of 6711395871 fish.
# After 194 days: total of 7369214611 fish.
# After 195 days: total of 8009895871 fish.
# After 196 days: total of 8744419787 fish.
# After 197 days: total of 9564513342 fish.
# After 198 days: total of 10380261864 fish.
# After 199 days: total of 11405781154 fish.
# After 200 days: total of 12347057136 fish.
# After 201 days: total of 13570161074 fish.
# After 202 days: total of 14721291742 fish.
# After 203 days: total of 16113634398 fish.
# After 204 days: total of 17574409213 fish.
# After 205 days: total of 19124681651 fish.
# After 206 days: total of 20970294496 fish.
# After 207 days: total of 22727319000 fish.
# After 208 days: total of 24975942228 fish.
# After 209 days: total of 27068348878 fish.
# After 210 days: total of 29683795472 fish.
# After 211 days: total of 32295700955 fish.
# After 212 days: total of 35238316049 fish.
# After 213 days: total of 38544703709 fish.
# After 214 days: total of 41852000651 fish.
# After 215 days: total of 45946236724 fish.
# After 216 days: total of 49795667878 fish.
# After 217 days: total of 54659737700 fish.
# After 218 days: total of 59364049833 fish.
# After 219 days: total of 64922111521 fish.
# After 220 days: total of 70840404664 fish.
# After 221 days: total of 77090316700 fish.
# After 222 days: total of 84490940433 fish.
# After 223 days: total of 91647668529 fish.
# After 224 days: total of 100605974424 fish.
# After 225 days: total of 109159717711 fish.
# After 226 days: total of 119581849221 fish.
# After 227 days: total of 130204454497 fish.
# After 228 days: total of 142012428221 fish.
# After 229 days: total of 155331345097 fish.
# After 230 days: total of 168737985229 fish.
# After 231 days: total of 185096914857 fish.
# After 232 days: total of 200807386240 fish.
# After 233 days: total of 220187823645 fish.
# After 234 days: total of 239364172208 fish.
# After 235 days: total of 261594277442 fish.
# After 236 days: total of 285535799594 fish.
# After 237 days: total of 310750413450 fish.
# After 238 days: total of 340428259954 fish.
# After 239 days: total of 369545371469 fish.
# After 240 days: total of 405284738502 fish.
# After 241 days: total of 440171558448 fish.
# After 242 days: total of 481782101087 fish.
# After 243 days: total of 524899971802 fish.
# After 244 days: total of 572344690892 fish.
# After 245 days: total of 625964059548 fish.
# After 246 days: total of 680295784919 fish.
# After 247 days: total of 745712998456 fish.
# After 248 days: total of 809716929917 fish.
# After 249 days: total of 887066839589 fish.
# After 250 days: total of 965071530250 fish.
# After 251 days: total of 1054126791979 fish.
# After 252 days: total of 1150864031350 fish.
# After 253 days: total of 1252640475811 fish.
# After 254 days: total of 1371677058004 fish.
# After 255 days: total of 1490012714836 fish.
# After 256 days: total of 1632779838045 fish.
# CPU times: user 45 ms, sys: 13.3 ms, total: 58.3 ms
# Wall time: 67 ms
